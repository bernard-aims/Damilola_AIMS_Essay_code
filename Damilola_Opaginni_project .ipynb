# %%
#plot with different borrowing rate
# %pylab
import numpy as np
import math as m
from matplotlib import pylab  as plt
from mpl_toolkits.mplot3d import Axes3D


s = np.linspace(0.3,1,100)

B = -0.5; a = 0.18; b = 0.15; R=0.8; L = 0.9; T =2; K =0.9;  S = 5; P =4; t=0


F = lambda s:m.exp((B*(a-(0.5*s**2)))*t)*(S*m.exp((a-(0.5*s**2))*t)-P*m.exp((b-(0.5*s**2))*t))

Fp = lambda s:m.exp((B*(a-(0.5*s**2)))*t)*(S*m.exp((a-(0.5*s**2))*t)*(a-(0.5*s**2))-
    (P*m.exp((b-(0.5*s**2))*t)*(b-(0.5*s**2))))+m.exp((B*(a-(0.5*s**2)))*t)*B*(a-(0.5*s**2))*(S*m.exp((a-(0.5*s**2))*t)-
    P*m.exp((b-(0.5*s**2))*t))
    
def p(x,dev,Fun,ra1,Beta,R,ra):
    f = (dev(x)/Fun(x)) + (0.5*(1+Beta)**2*x**2)
    if ra1 <= f-(R*((1+Beta)**2)*x**2):
        fi = (f-ra1)/(R*(1+Beta)**2*x**2)
    elif ra < f-(R*((1+Beta)**2)*x**2) and f-(R*((1+Beta)**2)*x**2) < ra1:
        fi = 1
    else :
        fi = (f-ra)/(R*(1+Beta)**2*x**2)
        
    return fi

y = []
for i in s:
    y.append(p(i,Fp,F,0.1,B,R,0.05))
z = []
for i in s:
    z.append(p(i,Fp,F,0.08,B,R,0.05))
w=[]
for i in s:
    w.append(p(i,Fp,F,0.12,B,R,0.05))
    
plt.plot(s,y,)
plt.plot(s,z,)        
plt.plot(s,w,)
plt.legend()

#plt.title('t=0',loc='right')
#plt.plot(s,y, [0.413598,0.413598],[0, 1],'--',[0.533102,0.533102],[0, 1],'--',[0.6,0.6],[0, 1],'--')
plt.xlim(0.2,1.1)
plt.ylim(0,2)
plt.plot([0.54079], [1], '*')
plt.annotate('(0.54079, 1)',
             xy=(0.54079,0.9),
             xycoords='data',
             xytext = (0.5, 0.5),
             va='bottom', ha = 'left', 
             textcoords='offset points',
             arrowprops=dict());
plt.plot([0.54079], [1.2606], '*')
plt.annotate('(0.54079,1.2606)',
             xy=(0.54079,1.2606),
             xycoords='data',
             xytext = (0.5, 0.5),
             va='bottom', ha = 'left', 
             textcoords='offset points',
             arrowprops=dict());
plt.plot([0.54079], [1.60204], '*') 
plt.annotate('(0.54079, 1.60204)',
             xy=(0.54079,1.60204),
             xycoords='data',
             xytext = (0.5, 0.5),
             va='bottom', ha = 'left', 
             textcoords='offset points',
             arrowprops=dict());
plt.plot([0.771266], [0.806122], '*')
plt.annotate('(0.771266,0.806122)',
             xy=(0.78,0.806122),
             xycoords='data',
             xytext = (0.5, 0.5),
             va='bottom', ha = 'left', 
             textcoords='offset points',
             arrowprops=dict());
plt.plot([0.771266], [0.719388], '*') 
plt.annotate('(0.771266, 0.719388)',
             xy=(0.8,0.7),
             xycoords='data',
             xytext = (0.5, 0.5),
             va='bottom', ha = 'left', 
             textcoords='offset points',
             arrowprops=dict());
plt.plot([0.771266], [0.627551], '*') 
plt.annotate('(0.771266, 0.627551)',
             xy=(0.73,0.5),
             xycoords='data',
             xytext = (0.5, 0.5),
             va='bottom', ha = 'left', 
             textcoords='offset points',
             arrowprops=dict());
plt.annotate('r1=0.1, r=0.05',
             xy=(0.48,1.8),
             xycoords='data',
             xytext = (-65, -60),
             va='bottom', ha = 'left', 
             textcoords='offset points',
             arrowprops=dict(arrowstyle = '->'));
plt.annotate('r1=0.12, r=0.65',
             xy=(0.4,1.9),
             xycoords='data',
             xytext = (-75, -30),
             va='bottom', ha = 'left', 
             textcoords='offset points',
             arrowprops=dict(arrowstyle = '->'));
plt.annotate('r1=0.08, r=0.04',
             xy=(0.52,1.9),
             xycoords='data',
             xytext = (30, -20),
             va='bottom', ha = 'left', 
             textcoords='offset points',
             arrowprops=dict(arrowstyle = '->'));


plt.ylabel('$\pi$*/w')
plt.xlabel('sigma') 
plt.savefig("hara.png")
plt.show()
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plt']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
#plot with different borrowing rate
# %pylab
import numpy as np
import math as m
from matplotlib import pylab  as plt
from mpl_toolkits.mplot3d import Axes3D


s = np.linspace(0.3,1,100)

B = -0.5; a = 0.18; b = 0.15; R=0.8; L = 0.9; T =2; K =0.9; r1 = 0.1;
r = 0.05; S = 5; P =4; t=0


F = lambda s:m.exp((B*(a-(0.5*s**2)))*t)*(S*m.exp((a-(0.5*s**2))*t)-P*m.exp((b-(0.5*s**2))*t))

Fp = lambda s:m.exp((B*(a-(0.5*s**2)))*t)*(S*m.exp((a-(0.5*s**2))*t)*(a-(0.5*s**2))-
    (P*m.exp((b-(0.5*s**2))*t)*(b-(0.5*s**2))))+m.exp((B*(a-(0.5*s**2)))*t)*B*(a-(0.5*s**2))*(S*m.exp((a-(0.5*s**2))*t)-
    P*m.exp((b-(0.5*s**2))*t))
    
def p(x,dev,Fun,ra1,Beta,R,ra):
    f = (dev(x)/Fun(x)) + (0.5*(1+Beta)**2*x**2)
    if ra1 <= f-(R*((1+Beta)**2)*x**2):
        fi = (f-ra1)/(R*(1+Beta)**2*x**2)
    elif ra < f-(R*((1+Beta)**2)*x**2) and f-(R*((1+Beta)**2)*x**2) < ra1:
        fi = 1
    else :
        fi = (f-ra)/(R*(1+Beta)**2*x**2)
        
    return fi

y = []
for i in s:
    y.append(p(i,Fp,F,0.1,B,R,0.05))
z = []
for i in s:
    z.append(p(i,Fp,F,0.1,B,R,0.04))
w=[]
for i in s:
    w.append(p(i,Fp,F,0.1,B,R,0.06))
    
plt.plot(s,y,)
plt.plot(s,z,)        
plt.plot(s,w,)
plt.legend()

#plt.title('t=0',loc='right')
#plt.plot(s,y, [0.413598,0.413598],[0, 1],'--',[0.533102,0.533102],[0, 1],'--',[0.6,0.6],[0, 1],'--')
plt.xlim(0.2,1.1)
plt.ylim(0,2)
plt.plot([0.771266], [0.806122], '*')
plt.annotate('(0.771266,0.806122)',
             xy=(0.78,0.806122),
             xycoords='data',
             xytext = (0.5, 0.5),
             va='bottom', ha = 'left', 
             textcoords='offset points',
             arrowprops=dict());
plt.plot([0.771266], [0.719388], '*') 
plt.annotate('(0.771266, 0.719388)',
             xy=(0.8,0.7),
             xycoords='data',
             xytext = (0.5, 0.5),
             va='bottom', ha = 'left', 
             textcoords='offset points',
             arrowprops=dict());
plt.plot([0.771266], [0.627551], '*') 
plt.annotate('(0.771266, 0.627551)',
             xy=(0.73,0.5),
             xycoords='data',
             xytext = (0.5, 0.5),
             va='bottom', ha = 'left', 
             textcoords='offset points',
             arrowprops=dict());


plt.ylabel('$\pi$*/w')
plt.xlabel('sigma') 
plt.savefig("hara.png")
plt.show()
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
#plot with different time

import numpy as np
import math as m
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter



B = -0.5; a = 0.18; b = 0.15; R=0.8; L = 0.9; T =2; K =0.9; r1 = 0.1;
r = 0.05; S = 3; P =2;


def p(x,ra1,Beta,R,ra,t):
    F = lambda s: m.exp((B * (a - (0.5 * s ** 2))) * t) * (S * m.exp((a - (0.5 * s ** 2)) * t) -
    P * m.exp((b - (0.5 * s ** 2)) * t))

    Fp = lambda s: m.exp((B * (a - (0.5 * s ** 2))) * t) * (S * m.exp((a - (0.5 * s ** 2)) * t) * (a - (0.5 * s ** 2)) -
    (P * m.exp((b - (0.5 * s ** 2)) * t) * (b - (0.5 * s ** 2)))) + \
    m.exp((B * (a - (0.5 * s ** 2))) * t) * B * (a - (0.5 * s ** 2)) * (S * m.exp((a - (0.5 * s ** 2)) * t) -
    P * m.exp((b - (0.5 * s ** 2)) * t))

    f = (Fp(x)/F(x)) + (0.5*(1+Beta)**2*x**2)
    if ra1 <= f-(R*((1+Beta)**2)*x**2):
        fi = (f-ra1)/(R*(1+Beta)**2*x**2)
    elif ra < f-(R*((1+Beta)**2)*x**2) and f-(R*((1+Beta)**2)*x**2) < ra1:
        fi = 1
    else :
        fi = (f-ra)/(R*(1+Beta)**2*x**2)

    return fi

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

s = np.arange(0.3, 1, 0.1)
T = np.arange(0, 4, 0.2)
X, Y = np.meshgrid(s, T)
zs = np.array([p(s,r1,B,R,r,T) for s,T in zip(np.ravel(X), np.ravel(Y))])
Z = zs.reshape(X.shape)



surf = ax.plot_surface(X,Y,Z)
ax.set_zlim(0, 2)
ax.set_zlabel("$\pi$/w")
ax.set_ylabel("time")
ax.set_xlabel("sigma")
plt.savefig("3d")
plt.show()
